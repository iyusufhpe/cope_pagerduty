# %% [markdown]
# # Getting Started with Pager Duty REST API

# %%
import pdpyras

# Replace with your actual API token
api_token = "u+8Az15bpgqsshiJ2_Ng"

# Create a session
session = pdpyras.APISession(api_token, verify=False)

# Make the request to get abilities
response = session.rget("/abilities")

# Print the response
print(response)
# Out:
# GET https://api.pagerduty.com/abilities: HTTP or network error: SSLError. retrying in 3 seconds.
# GET https://api.pagerduty.com/abilities: HTTP or network error: SSLError. retrying in 6 seconds.
# GET https://api.pagerduty.com/abilities: HTTP or network error: SSLError. retrying in 12 seconds.
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Users\yusufi\OneDrive - Hewlett Packard Enterprise\Projects\cope_pagerduty\.virtualenv\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# ...
